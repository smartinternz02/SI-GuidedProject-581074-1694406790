# %% [markdown]
# # Data Visuvalization on the car_crashes dataset

# %%
import seaborn as sns

# %% [markdown]
# Importing the required libraries for the visualization of the car_crashes dataset

# %%
data=sns.load_dataset("car_crashes")

# %% [markdown]
#  loading the car_crashes dataset

# %%
data.shape
# Out:
# (51, 8)

# %% [markdown]
# printing the shape of the dataset

# %%
data
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# displaying the head of the dataset.

# %%
data.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %% [markdown]
# displaying the tail of the dataset.

# %%
data.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %% [markdown]
# Descibing the data set

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# information of the car_crashes dataset

# %%
data.isnull().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
data.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7868\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %% [markdown]
# displayin the correlation matrix

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7868\2578434383.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %% [markdown]
# displaying the heatmap of the correlation matrix

# %%
sns.scatterplot(x="speeding",y="total",data=data)
# Out:
# <Axes: xlabel='speeding', ylabel='total'>

# %% [markdown]
# Bivariate analysis: From the scatterplot of total vs speeding , we can say that the total value is directly proportional to the speeding . total and speeding are strongly correlated.

# %%
sns.scatterplot(x="speeding",y="alcohol",data=data)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %% [markdown]
# Bivariate analysis: From the scatterplot of alcohol vs speeding , we can say that the alcohol value is directly proportional to the speeding . alcohol and speeding are strongly correlated.

# %%
sns.scatterplot(x="ins_premium",y="total",data=data)
# Out:
# <Axes: xlabel='ins_premium', ylabel='total'>

# %% [markdown]
# Bivariate analysis: From the scatterplot of total vs ins_premium , we can say that the total value is inversly proportional to the ins_premium . total and ins_premium are weakly corrr=elated.

# %%
sns.scatterplot(x="no_previous",y="total",data=data)
# Out:
# <Axes: xlabel='no_previous', ylabel='total'>

# %% [markdown]
# Bivariate analysis: From the scatterplot of total vs no_previous , we can say that the total value is directly proportional to the no_previous . total and no_previous are strongly correlated.

# %%
sns.scatterplot(x="not_distracted",y="no_previous",data=data)
# Out:
# <Axes: xlabel='not_distracted', ylabel='no_previous'>

# %% [markdown]
# Bivariate analysis: From the scatterplot of total vs not_distracted. , we can say that the total value is directly proportional to the not_distracted . total and not_distracted are strongly correlated.

# %%
sns.lineplot(x="speeding",y="alcohol",data=data)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %% [markdown]
# form the lineplot the we can observe the change in alcohol with respect to the speeding value.

# %%
sns.distplot(data.total)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7868\2102236082.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.total)
# <Axes: xlabel='total', ylabel='Density'>

# %% [markdown]
# Univariate analysis : from the distplot we can display the distribution of the total values in the given car_crashes dataset.

# %%
sns.distplot(data.speeding)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7868\2228035885.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.speeding)
# <Axes: xlabel='speeding', ylabel='Density'>

# %% [markdown]
# Univariate analysis : from the distplot we can display the distribution of the speeding values in the given car_crashes dataset.

# %%
sns.distplot(data.alcohol)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7868\1638773409.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.alcohol)
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# Univariate analysis : from the distplot we can display the distribution of the alcohol values in the given car_crashes dataset.

# %%
sns.distplot(data.not_distracted)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7868\1797917329.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.not_distracted)
# <Axes: xlabel='not_distracted', ylabel='Density'>

# %% [markdown]
# Univariate analysis : from the distplot we can display the distribution of the not-distracted values in the given car_crashes dataset.

# %%
sns.distplot(data.no_previous)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7868\1836816757.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.no_previous)
# <Axes: xlabel='no_previous', ylabel='Density'>

# %% [markdown]
# Univariate analysis : from the distplot we can display the distribution of the no_previous values in the given car_crashes dataset.

# %%
sns.distplot(data.ins_premium)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7868\2655982644.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.ins_premium)
# <Axes: xlabel='ins_premium', ylabel='Density'>

# %% [markdown]
# Univariate analysis : from the distplot we can display the distribution of the ins_premium values in the given car_crashes dataset.

# %%
sns.distplot(data.ins_losses)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_7868\1689502277.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.ins_losses)
# <Axes: xlabel='ins_losses', ylabel='Density'>

# %% [markdown]
# Univariate analysis : from the distplot we can display the distribution of the ins_losses values in the given car_crashes dataset.

# %%
data.abbrev.value_counts()
# Out:
# AL    1
# PA    1
# NV    1
# NH    1
# NJ    1
# NM    1
# NY    1
# NC    1
# ND    1
# OH    1
# OK    1
# OR    1
# RI    1
# MT    1
# SC    1
# SD    1
# TN    1
# TX    1
# UT    1
# VT    1
# VA    1
# WA    1
# WV    1
# WI    1
# NE    1
# MO    1
# AK    1
# ID    1
# AZ    1
# AR    1
# CA    1
# CO    1
# CT    1
# DE    1
# DC    1
# FL    1
# GA    1
# HI    1
# IL    1
# MS    1
# IN    1
# IA    1
# KS    1
# KY    1
# LA    1
# ME    1
# MD    1
# MA    1
# MI    1
# MN    1
# WY    1
# Name: abbrev, dtype: int64

# %% [markdown]
# finding the different values and there respective counts in the abbrev attribute in the car_crashes dataset.

# %%
sns.barplot(data=data,x="abbrev",y="total")
# Out:
# <Axes: xlabel='abbrev', ylabel='total'>

# %% [markdown]
# form the above graph and value_counts() we can say that there no value repeated, the bar plot was drawn between the total vs abbrev .

# %%
sns.jointplot(x="alcohol",y="total",data=data,kind='reg')

# %% [markdown]
# Jointplot between the total vs alcohol, we can find the distributions of the both attributes and  that they are strongly correlated
# with each other.

# %%
sns.jointplot(x="alcohol",y="total",data=data,kind='hex')

# %% [markdown]
# Jointplot between the total vs alcohol, we can find the distributions of the both attributes . More number of cars are concentated at darkly shaded region of the hexagon

# %%
sns.jointplot(x="speeding",y="alcohol",data=data,kind='reg')

# %% [markdown]
# Jointplot between the alcohol vs speeding, we can find the distributions of the both attributes and  that they are strongly correlated with each other.

# %%
sns.jointplot(x="speeding",y="alcohol",data=data,kind='hex')

# %% [markdown]
# Jointplot between the alcohol vs speeding, we can find the distributions of the both attributes . More number of cars are concentated at darkly shaded region of the hexagon

# %%
sns.boxplot(x="abbrev",y="total",data=data)
# Out:
# <Axes: xlabel='abbrev', ylabel='total'>

# %% [markdown]
# univariate analysis : we can observe the boxplot between the numerical value total and categorical value abbrev from the above plot. By finding the boxplot we can find the intervals in which the data had distributed and if there are any outliers in the data.

# %%
sns.pairplot(data)

# %% [markdown]
# Multivariate analysis : we can observe the coorelation among the numerical values in the car_crashes dataset by plotting the paiplot of the car-crashes dataset.
